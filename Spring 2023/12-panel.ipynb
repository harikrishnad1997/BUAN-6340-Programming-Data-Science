# %% [markdown]
# # Data Science: Microeconomic panel data

# %%
import warnings
import numpy as np
import pandas as pd
from cleands import *
from itertools import product

class panelDF(pd.DataFrame):
    def __init__(self,*args,**kwargs):
        id_dim = kwargs.pop('id',None)
        time_dim = kwargs.pop('time',None)
        super(panelDF,self).__init__(*args,**kwargs)    
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            self.id = id_dim
            self.time = time_dim
        self.sort_values(by=[id_dim,time_dim],inplace=True)
    def outer_balance(self):
        for j in product(self[self.id].unique(),self[self.time].unique()):
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                rows = self[self[self.id]==j[0]][self[self.time]==j[1]]
            if len(rows)<1:
                data = {i:np.nan for i in self.columns}            
                data[self.id] = j[0]
                data[self.time] = j[1]
                row = pd.DataFrame(data,index=[0])
                df = pd.concat((self,row),axis=0,ignore_index=True)
                self = panelDF(df,id=self.id,time=self.time)
            elif len(rows)>1:
                raise Exception('duplicate rows')
        return self

# %%
df = pd.read_csv('JTRAIN.csv')
df = df[['year','fcode','scrap','grant','grant_1']]
df['lscrap'] = np.log(df['scrap'])
df = df.dropna()
#df = df[df.index!=30]
df = panelDF(df,id='fcode',time='year')
df = df.outer_balance()
df
# Out:
#      year   fcode  scrap  grant  grant_1    lscrap
# 30   1987  410523   0.06      0        0 -2.813411
# 31   1988  410523   0.05      0        0 -2.995732
# 32   1989  410523   0.05      0        0 -2.995732
# 48   1987  410538   2.64      0        0  0.970779
# 49   1988  410538   2.74      0        0  1.007958
# ..    ...     ...    ...    ...      ...       ...
# 463  1988  419482   2.59      0        0  0.951658
# 464  1989  419482   2.80      0        0  1.029619
# 465  1987  419483  20.00      0        0  2.995732
# 466  1988  419483  25.00      0        0  3.218876
# 467  1989  419483  30.00      0        0  3.401197
#
# [162 rows x 6 columns]

# %%
162/3
# Out:
# 54.0

# %%
# Pooled OLS
LeastSquaresRegressor(*add_intercept(['grant','grant_1'],'lscrap',df)).tidy
# Out:
#       variable              estimate            std.error  \
# 0  (intercept)   0.41505637487690583  0.13982796899679673
# 1        grant   0.05435340639144301  0.31050104728953193
# 2      grant_1  -0.26521024220789774   0.3699500322967739
#
#            t.statistic                p.value
# 0   2.9683358619505817  0.0034576102640516255
# 1  0.17505063788322833     0.8612625593662346
# 2  -0.7168812516689986     0.4744991094744584

# %%
ddf = df.copy()
means_t = ddf[df.columns].groupby(df.time).mean().reset_index()[df.columns]
np.kron(np.ones((len(df[df.id].unique()),1)),means_t).shape
# Out:
# (162, 6)

# %%
np.kron(np.ones((3,1)),means_t)
# Out:
# array([[1.98700000e+03, 4.16313574e+05, 4.61166667e+00, 0.00000000e+00,
#         0.00000000e+00, 5.97434051e-01],
#        [1.98800000e+03, 4.16313574e+05, 3.78777778e+00, 3.51851852e-01,
#         0.00000000e+00, 4.28440922e-01],
#        [1.98900000e+03, 4.16313574e+05, 3.13148148e+00, 1.85185185e-01,
#         3.51851852e-01, 1.55169229e-01],
#        [1.98700000e+03, 4.16313574e+05, 4.61166667e+00, 0.00000000e+00,
#         0.00000000e+00, 5.97434051e-01],
#        [1.98800000e+03, 4.16313574e+05, 3.78777778e+00, 3.51851852e-01,
#         0.00000000e+00, 4.28440922e-01],
#        [1.98900000e+03, 4.16313574e+05, 3.13148148e+00, 1.85185185e-01,
#         3.51851852e-01, 1.55169229e-01],
#        [1.98700000e+03, 4.16313574e+05, 4.61166667e+00, 0.00000000e+00,
#         0.00000000e+00, 5.97434051e-01],
#        [1.98800000e+03, 4.16313574e+05, 3.78777778e+00, 3.51851852e-01,
#         0.00000000e+00, 4.28440922e-01],
#        [1.98900000e+03, 4.16313574e+05, 3.13148148e+00, 1.85185185e-01,
#         3.51851852e-01, 1.55169229e-01]])

# %%
ddf = df.copy()
means_t = ddf[df.columns].groupby(df.time).mean().reset_index()[df.columns]
ddf -= np.kron(np.ones((len(df[df.id].unique()),1)),means_t)

# Common time effects
model = LeastSquaresRegressor(['grant','grant_1'],'lscrap',ddf)
model.tidy
# Out:
#   variable             estimate          std.error          t.statistic  \
# 0    grant  0.20001966562375645  0.335098178670527   0.5968986952340868
# 1  grant_1    0.048935698577833  0.431958857393869  0.11328786929634001
#
#               p.value
# 0  0.5514187067373635
# 1   0.909944354348349

# %%
time_fe = means_t[model.y_var]-means_t[model.x_vars]@model.params
time_fe
# Out:
# 0    0.597434
# 1    0.358064
# 2    0.100910
# dtype: float64

# %%
means_t
# Out:
#    year          fcode     scrap     grant   grant_1    lscrap
# 0  1987  416313.574074  4.611667  0.000000  0.000000  0.597434
# 1  1988  416313.574074  3.787778  0.351852  0.000000  0.428441
# 2  1989  416313.574074  3.131481  0.185185  0.351852  0.155169

# %%
np.kron(means_i,np.ones((T,1)))
# Out:
# array([[1., 2.],
#        [1., 2.],
#        [1., 2.],
#        [3., 4.],
#        [3., 4.],
#        [3., 4.]])

# %%
ddf = df.copy()
means_i = ddf[df.columns].groupby(df.id).mean().reset_index()[df.columns]
ddf -= np.kron(means_i,np.ones((len(df[df.time].unique()),1)))

# %%
ddf = df.copy()
means_i = ddf[df.columns].groupby(df.id).mean().reset_index()[df.columns]
ddf -= np.kron(means_i,np.ones((len(df[df.time].unique()),1)))
means_t = ddf[df.columns].groupby(df.time).mean().reset_index()[df.columns]
ddf -= np.kron(np.ones((len(df[df.id].unique()),1)),means_t)

# Two way effects
model = LeastSquaresRegressor(['grant','grant_1'],'lscrap',ddf)
model.tidy
# Out:
#   variable             estimate            std.error          t.statistic  \
# 0    grant  -0.2523148711500044  0.12144097568600476   -2.077674934055079
# 1  grant_1  -0.4215895094264221  0.16946862639252946  -2.4877142064627407
#
#                 p.value
# 0    0.0393367004795288
# 1  0.013881528983727506

# %%
n = len(df[df.id].unique())
T = len(df[df.time].unique())
x = model.x.values
r = x.shape[1]
e = model.residuals.values.reshape(-1,1)
vc = np.zeros((r,r))
for i in range(n):
    xi = x[i*T:(i+1)*T,:]
    ei = e[i*T:(i+1)*T,:]
    vc += xi.T@ei@ei.T@xi
ixx = np.linalg.inv(x.T@x)
vc = ixx@vc@ixx
vc # arellano 1987 HAC estimator
# Out:
# array([[0.01969226, 0.03448178],
#        [0.03448178, 0.07636089]])

# %%
15*16/2
# Out:
# 120.0

# %%
se = np.sqrt(np.diag(vc))
se
# Out:
# array([0.14032911, 0.27633474])

# %%
model.tidy
# Out:
#   variable             estimate            std.error          t.statistic  \
# 0    grant  -0.2523148711500044  0.12144097568600476   -2.077674934055079
# 1  grant_1  -0.4215895094264221  0.16946862639252946  -2.4877142064627407
#
#                 p.value
# 0    0.0393367004795288
# 1  0.013881528983727506

# %%
-0.2523148711500044/0.14032911
# Out:
# -1.7980223144720606

# %%
indiv_fe = means_i[model.y_var]-means_i[model.x_vars]@model.params
time_fe = means_t[model.y_var]-means_t[model.x_vars]@model.params
time_fe
# Out:
# 0    0.109139
# 1    0.028924
# 2   -0.138063
# dtype: float64

# %%
indiv_fe
# Out:
# 0    -2.934958
# 1     0.970300
# 2     1.782369
# 3     1.508709
# 4     1.686475
# 5    -0.655371
# 6     0.488189
# 7     3.191661
# 8     0.000000
# 9     1.826880
# 10   -0.811978
# 11   -0.226734
# 12   -0.388636
# 13    0.072952
# 14   -3.009340
# 15   -1.756123
# 16    1.589416
# 17    0.224635
# 18    1.724571
# 19    0.693147
# 20   -0.503633
# 21    0.429336
# 22    0.447245
# 23   -0.335033
# 24    0.821888
# 25    0.598433
# 26    0.564796
# 27   -0.272717
# 28   -0.773943
# 29   -0.376575
# 30    1.685310
# 31    2.229614
# 32   -2.807294
# 33    3.133029
# 34   -1.289743
# 35    1.871849
# 36    0.693147
# 37    1.712000
# 38    0.208226
# 39    3.094669
# 40    0.316692
# 41   -1.363318
# 42   -0.008913
# 43   -0.673096
# 44    1.448886
# 45    0.084105
# 46    0.653548
# 47   -0.581296
# 48    2.173804
# 49    0.890894
# 50    1.608904
# 51    0.514148
# 52    0.991510
# 53    3.205268
# dtype: float64

# %%
# %pip install --user linearmodels
# Out:
# Requirement already satisfied: linearmodels in c:\users\jason\appdata\roaming\python\python39\site-packages (4.27)
# Requirement already satisfied: scipy>=1.2 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (1.7.3)
# Requirement already satisfied: property-cached>=1.6.3 in c:\users\jason\appdata\roaming\python\python39\site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: Cython>=0.29.21 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (0.29.28)
# Requirement already satisfied: numpy>=1.16 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (1.21.5)
# Requirement already satisfied: setuptools-scm<7.0.0,>=6.4.2 in c:\users\jason\appdata\roaming\python\python39\site-packages (from linearmodels) (6.4.2)
# Requirement already satisfied: pyhdfe>=0.1 in c:\users\jason\appdata\roaming\python\python39\site-packages (from linearmodels) (0.1.1)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: statsmodels>=0.11 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (0.13.2)
# Requirement already satisfied: pandas>=0.24 in c:\users\jason\anaconda3\lib\site-packages (from linearmodels) (1.4.2)
# Requirement already satisfied: formulaic~=0.3.2 in c:\users\jason\appdata\roaming\python\python39\site-packages (from linearmodels) (0.3.4)
# Requirement already satisfied: wrapt>=1.0 in c:\users\jason\anaconda3\lib\site-packages (from formulaic~=0.3.2->linearmodels) (1.12.1)
# Requirement already satisfied: astor>=0.8 in c:\users\jason\appdata\roaming\python\python39\site-packages (from formulaic~=0.3.2->linearmodels) (0.8.1)
# Requirement already satisfied: interface-meta<2.0.0,>=1.2.0 in c:\users\jason\appdata\roaming\python\python39\site-packages (from formulaic~=0.3.2->linearmodels) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jason\anaconda3\lib\site-packages (from pandas>=0.24->linearmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jason\anaconda3\lib\site-packages (from pandas>=0.24->linearmodels) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jason\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24->linearmodels) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\jason\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (1.2.2)
# Requirement already satisfied: setuptools in c:\users\jason\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (61.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jason\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jason\anaconda3\lib\site-packages (from packaging>=20.0->setuptools-scm<7.0.0,>=6.4.2->linearmodels) (3.0.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\jason\anaconda3\lib\site-packages (from statsmodels>=0.11->linearmodels) (0.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = df.set_index(['fcode','year'])

# %%
from linearmodels import PanelOLS
mod = PanelOLS(df.lscrap, df[['grant','grant_1']], entity_effects=True, time_effects=True)
res = mod.fit(cov_type='kernel')
res
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 lscrap   R-squared:                        0.0411
# Estimator:                   PanelOLS   R-squared (Between):             -0.0552
# No. Observations:                 162   R-squared (Within):               0.1478
# Date:                Wed, Nov 16 2022   R-squared (Overall):             -0.0381
# Time:                        13:11:07   Log-likelihood                   -80.946
# Cov. Estimator:        Driscoll-Kraay
#                                         F-statistic:                      2.2294
# Entities:                          54   P-value                           0.1127
# Avg Obs:                       3.0000   Distribution:                   F(2,104)
# Min Obs:                       3.0000
# Max Obs:                       3.0000   F-statistic (robust):             92.755
#                                         P-value                           0.0000
# Time periods:                       3   Distribution:                   F(2,104)
# Avg Obs:                       54.000
# Min Obs:                       54.000
# Max Obs:                       54.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# grant         -0.2523     0.0540    -4.6702     0.0000     -0.3595     -0.1452
# grant_1       -0.4216     0.0602    -6.9991     0.0000     -0.5410     -0.3021
# ==============================================================================
#
# F-test for Poolability: 24.118
# P-value: 0.0000
# Distribution: F(55,104)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x2572794d9d0

# %% [markdown]
# # Data Science: Macroeconomic panel data

# %%
df = pd.read_csv('PRISON.csv')
gb = df.groupby(['year'])['criv'].apply(list).apply(pd.Series).rename(columns=lambda x: 'State_{0}'.format(x+1))
gb
# Out:
#        State_1   State_2   State_3   State_4    State_5   State_6   State_7  \
# year
# 80    4.447868  4.773632  6.502207  3.349081   8.884993  5.264706  4.108108
# 81    4.700944  6.069378  5.723132  3.104666   8.584576  5.290463  4.484819
# 82    4.497580  6.071111  5.115917  3.242371   8.115592  5.014369  4.013062
# 83    4.186833  6.024590  4.931627  3.005204   7.669203  4.771857  3.721379
# 84    4.353239  6.046692  5.137268  3.253879   7.568062  4.589274  3.906289
# 85    4.630758  5.697369  6.030779  3.523421   7.630687  4.742599  3.985630
# 86    5.665331  5.599265  6.600665  4.015866   9.164268  5.284214  4.211538
# 87    5.686924  4.435993  6.034914  4.201110   9.142204  4.726687  4.143825
# 88    5.728628  4.948339  5.982178  4.369185   9.201518  4.766401  4.510697
# 89    6.036973  4.795247  5.886250  4.858056   9.724690  4.772894  5.049040
# 90    7.069136  5.207581  6.495789  5.312527  10.406870  5.236628  5.535584
# 91    8.439609  6.149385  6.714362  5.935049  10.889660  5.604451  5.398480
# 92    8.712421  6.593537  6.708246  5.777360  11.187050  5.796825  4.956389
# 93    7.804156  7.607679  7.149899  5.932756  10.777640  5.672742  4.561794
#
#        State_8   State_9   State_10  ...  State_42  State_43  State_44  \
# year                                 ...
# 80    4.754209  20.75549   9.654730  ...  1.263386  4.535831  5.480217
# 81    5.107383  23.61852   9.625134  ...  1.040580  4.109550  5.327547
# 82    5.626043  21.91640   8.920924  ...  0.989870  4.215669  5.751615
# 83    4.538843  19.57120   8.213209  ...  1.212121  4.042060  5.113382
# 84    4.364379  17.71406   8.629529  ...  1.493544  4.482612  5.043856
# 85    4.360841  16.02992   9.423927  ...  1.385387  4.791516  5.532477
# 86    4.304140  14.76959  10.371360  ...  1.268678  5.469297  6.637582
# 87    4.354788  15.72371  10.266570  ...  1.219828  5.415011  6.374744
# 88    4.600308  18.91111  11.241910  ...  1.164756  5.434467  6.569808
# 89    5.691489  20.73237  11.123200  ...  1.390244  5.586732  6.657286
# 90    6.524663  24.70033  12.379080  ...  1.625538  6.683974  7.581653
# 91    7.132159  24.69865  11.846830  ...  1.824786  7.260703  8.399204
# 92    6.193922  28.52137  12.076470  ...  1.953390  7.460100  8.051179
# 93    6.858572  29.21799  12.060460  ...  2.083916  7.657776  7.621264
#
#       State_45  State_46  State_47  State_48  State_49  State_50  State_51
# year
# 80    3.028747  1.788650  3.058724  4.621975  1.818974  1.815980  3.917021
# 81    2.988119  1.277132  3.206466  4.447356  1.745138  1.884046  4.300813
# 82    2.849808  1.262042  3.089386  4.033435  1.746154  1.919433  3.017787
# 83    2.598119  1.330784  2.917520  3.717674  1.735219  1.921203  2.390196
# 84    2.487669  1.459203  2.951807  4.069061  1.702801  1.977829  2.449505
# 85    2.676811  1.490566  2.941907  4.262955  1.685370  2.080876  2.614000
# 86    2.670475  1.511236  3.046800  4.380193  1.676939  2.594407  2.995968
# 87    2.300954  1.385185  2.935604  4.400927  1.402045  2.514441  2.907757
# 88    2.433393  1.438182  2.971675  4.642888  1.353005  2.159685  3.180645
# 89    2.589097  1.349462  3.113889  4.732406  1.507471  2.230595  2.679039
# 90    2.824480  1.269504  3.495086  4.984684  1.691365  2.640832  3.011013
# 91    2.873231  1.165493  3.730757  5.228070  1.912173  2.774004  3.115721
# 92    2.908338  1.092820  3.738974  5.338130  2.118850  2.765071  3.202151
# 93    3.010215  1.142361  3.722077  5.145576  2.084066  2.644105  2.861702
#
# [14 rows x 51 columns]

# %%
df = pd.read_csv('PRISON.csv')
gb = df.groupby(['year'])['criv'].apply(list).apply(pd.Series).rename(columns=lambda x: 'State_{0}'.format(x+1))
gb
# Out:
#        State_1   State_2   State_3   State_4    State_5   State_6   State_7  \
# year
# 80    4.447868  4.773632  6.502207  3.349081   8.884993  5.264706  4.108108
# 81    4.700944  6.069378  5.723132  3.104666   8.584576  5.290463  4.484819
# 82    4.497580  6.071111  5.115917  3.242371   8.115592  5.014369  4.013062
# 83    4.186833  6.024590  4.931627  3.005204   7.669203  4.771857  3.721379
# 84    4.353239  6.046692  5.137268  3.253879   7.568062  4.589274  3.906289
# 85    4.630758  5.697369  6.030779  3.523421   7.630687  4.742599  3.985630
# 86    5.665331  5.599265  6.600665  4.015866   9.164268  5.284214  4.211538
# 87    5.686924  4.435993  6.034914  4.201110   9.142204  4.726687  4.143825
# 88    5.728628  4.948339  5.982178  4.369185   9.201518  4.766401  4.510697
# 89    6.036973  4.795247  5.886250  4.858056   9.724690  4.772894  5.049040
# 90    7.069136  5.207581  6.495789  5.312527  10.406870  5.236628  5.535584
# 91    8.439609  6.149385  6.714362  5.935049  10.889660  5.604451  5.398480
# 92    8.712421  6.593537  6.708246  5.777360  11.187050  5.796825  4.956389
# 93    7.804156  7.607679  7.149899  5.932756  10.777640  5.672742  4.561794
#
#        State_8   State_9   State_10  ...  State_42  State_43  State_44  \
# year                                 ...
# 80    4.754209  20.75549   9.654730  ...  1.263386  4.535831  5.480217
# 81    5.107383  23.61852   9.625134  ...  1.040580  4.109550  5.327547
# 82    5.626043  21.91640   8.920924  ...  0.989870  4.215669  5.751615
# 83    4.538843  19.57120   8.213209  ...  1.212121  4.042060  5.113382
# 84    4.364379  17.71406   8.629529  ...  1.493544  4.482612  5.043856
# 85    4.360841  16.02992   9.423927  ...  1.385387  4.791516  5.532477
# 86    4.304140  14.76959  10.371360  ...  1.268678  5.469297  6.637582
# 87    4.354788  15.72371  10.266570  ...  1.219828  5.415011  6.374744
# 88    4.600308  18.91111  11.241910  ...  1.164756  5.434467  6.569808
# 89    5.691489  20.73237  11.123200  ...  1.390244  5.586732  6.657286
# 90    6.524663  24.70033  12.379080  ...  1.625538  6.683974  7.581653
# 91    7.132159  24.69865  11.846830  ...  1.824786  7.260703  8.399204
# 92    6.193922  28.52137  12.076470  ...  1.953390  7.460100  8.051179
# 93    6.858572  29.21799  12.060460  ...  2.083916  7.657776  7.621264
#
#       State_45  State_46  State_47  State_48  State_49  State_50  State_51
# year
# 80    3.028747  1.788650  3.058724  4.621975  1.818974  1.815980  3.917021
# 81    2.988119  1.277132  3.206466  4.447356  1.745138  1.884046  4.300813
# 82    2.849808  1.262042  3.089386  4.033435  1.746154  1.919433  3.017787
# 83    2.598119  1.330784  2.917520  3.717674  1.735219  1.921203  2.390196
# 84    2.487669  1.459203  2.951807  4.069061  1.702801  1.977829  2.449505
# 85    2.676811  1.490566  2.941907  4.262955  1.685370  2.080876  2.614000
# 86    2.670475  1.511236  3.046800  4.380193  1.676939  2.594407  2.995968
# 87    2.300954  1.385185  2.935604  4.400927  1.402045  2.514441  2.907757
# 88    2.433393  1.438182  2.971675  4.642888  1.353005  2.159685  3.180645
# 89    2.589097  1.349462  3.113889  4.732406  1.507471  2.230595  2.679039
# 90    2.824480  1.269504  3.495086  4.984684  1.691365  2.640832  3.011013
# 91    2.873231  1.165493  3.730757  5.228070  1.912173  2.774004  3.115721
# 92    2.908338  1.092820  3.738974  5.338130  2.118850  2.765071  3.202151
# 93    3.010215  1.142361  3.722077  5.145576  2.084066  2.644105  2.861702
#
# [14 rows x 51 columns]

# %%
def kpss(series,trend=False,lagshort=True):
    y = series.values if type(series)==pd.Series else series
    n = y.shape[0]
    if lagshort: 
        lags = int(4*(n/100)**0.25)
    else: 
        lags = int(12*(n/100)**0.25)
    y = y.reshape(-1,1)
    x = np.ones((n,1))
    if trend:
        x = np.hstack((x,np.arange(n).reshape(-1,1)))
        table = np.array([0.119,0.146,0.176,0.216])
    else:
        table = np.array([0.347,0.463,0.574,0.739])
    tablep = np.array([0.1,0.05,0.025,0.01])
    res = y-x@np.linalg.solve(x.T@x,x.T@y)
    s = res.cumsum(0)
    eta = s.T@s/n**2
    sig = [2*(1-i/(lags+1))*(res[i:,:].T@res[:res.shape[0]-i,:])[0,0]/res[i:,:].shape[0] for i in range(1,lags+1)]
    sig = np.array(sig).sum()
    sig += (res.T@res)[0,0]/res.shape[0]
    stat = eta/sig
    p = np.interp(stat,table,tablep)
    df = pd.DataFrame(columns=['method','stat','lags','p'])
    df.loc[0] = ['kpss',stat[0,0],lags,p[0,0]]
    return df

# %%
kpss(gb.mean(1).diff().dropna())
# Out:
#   method      stat  lags    p
# 0   kpss  0.297749     2  0.1

# %%
for i in range(51):
    print(kpss(gb.values[:,i]))
# Out:
#   method      stat  lags         p
# 0   kpss  0.476136     2  0.047041
#   method      stat  lags    p
# 0   kpss  0.151532     2  0.1
#   method      stat  lags         p
# 0   kpss  0.350579     2  0.098457
#   method      stat  lags         p
# 0   kpss  0.498951     2  0.041903
#   method      stat  lags         p
# 0   kpss  0.426743     2  0.065628
#   method      stat  lags    p
# 0   kpss  0.247562     2  0.1
#   method      stat  lags        p
# 0   kpss  0.350388     2  0.09854
#   method      stat  lags    p
# 0   kpss  0.337382     2  0.1
#   method      stat  lags    p
# 0   kpss  0.253696     2  0.1
#   method      stat  lags         p
# 0   kpss  0.449728     2  0.055721
#   method      stat  lags         p
# 0   kpss  0.435551     2  0.061831
#   method     stat  lags    p
# 0   kpss  0.10984     2  0.1
#   method      stat  lags    p
# 0   kpss  0.149069     2  0.1
#   method      stat  lags         p
# 0   kpss  0.503912     2  0.040786
#   method      stat  lags         p
# 0   kpss  0.405482     2  0.074792
#   method      stat  lags         p
# 0   kpss  0.505329     2  0.040466
#   method      stat  lags         p
# 0   kpss  0.413486     2  0.071342
#   method      stat  lags         p
# 0   kpss  0.485026     2  0.045039
#   method      stat  lags        p
# 0   kpss  0.498433     2  0.04202
#   method      stat  lags         p
# 0   kpss  0.540008     2  0.032656
#   method      stat  lags    p
# 0   kpss  0.313967     2  0.1
#   method      stat  lags        p
# 0   kpss  0.386603     2  0.08293
#   method      stat  lags         p
# 0   kpss  0.424481     2  0.066603
#   method      stat  lags        p
# 0   kpss  0.484399     2  0.04518
#   method      stat  lags         p
# 0   kpss  0.361611     2  0.093702
#   method     stat  lags         p
# 0   kpss  0.43476     2  0.062172
#   method      stat  lags        p
# 0   kpss  0.376649     2  0.08722
#   method      stat  lags         p
# 0   kpss  0.511153     2  0.039155
#   method      stat  lags    p
# 0   kpss  0.200363     2  0.1
#   method      stat  lags    p
# 0   kpss  0.144241     2  0.1
#   method     stat  lags    p
# 0   kpss  0.20684     2  0.1
#   method      stat  lags         p
# 0   kpss  0.419737     2  0.068648
#   method      stat  lags    p
# 0   kpss  0.303507     2  0.1
#   method      stat  lags         p
# 0   kpss  0.464131     2  0.049745
#   method      stat  lags         p
# 0   kpss  0.374438     2  0.088173
#   method      stat  lags    p
# 0   kpss  0.246391     2  0.1
#   method      stat  lags         p
# 0   kpss  0.455731     2  0.053133
#   method      stat  lags    p
# 0   kpss  0.185959     2  0.1
#   method      stat  lags         p
# 0   kpss  0.381483     2  0.085137
#   method      stat  lags    p
# 0   kpss  0.150019     2  0.1
#   method      stat  lags         p
# 0   kpss  0.465081     2  0.049531
#   method      stat  lags         p
# 0   kpss  0.428777     2  0.064751
#   method      stat  lags         p
# 0   kpss  0.499125     2  0.041864
#   method      stat  lags         p
# 0   kpss  0.475658     2  0.047149
#   method      stat  lags    p
# 0   kpss  0.147365     2  0.1
#   method      stat  lags         p
# 0   kpss  0.383434     2  0.084296
#   method      stat  lags         p
# 0   kpss  0.360212     2  0.094305
#   method      stat  lags         p
# 0   kpss  0.397593     2  0.078193
#   method      stat  lags    p
# 0   kpss  0.157662     2  0.1
#   method      stat  lags         p
# 0   kpss  0.494688     2  0.042863
#   method      stat  lags    p
# 0   kpss  0.165885     2  0.1

# %%
for i in range(51):
    print(kpss(gb.values[:-1,i]-gb.values[1:,i]))
# Out:
#   method      stat  lags    p
# 0   kpss  0.130792     2  0.1
#   method      stat  lags    p
# 0   kpss  0.185776     2  0.1
#   method      stat  lags    p
# 0   kpss  0.228057     2  0.1
#   method      stat  lags    p
# 0   kpss  0.250979     2  0.1
#   method      stat  lags    p
# 0   kpss  0.218162     2  0.1
#   method      stat  lags    p
# 0   kpss  0.230104     2  0.1
#   method      stat  lags    p
# 0   kpss  0.117884     2  0.1
#   method      stat  lags    p
# 0   kpss  0.168877     2  0.1
#   method      stat  lags    p
# 0   kpss  0.266638     2  0.1
#   method      stat  lags    p
# 0   kpss  0.153876     2  0.1
#   method      stat  lags    p
# 0   kpss  0.150953     2  0.1
#   method      stat  lags    p
# 0   kpss  0.285337     2  0.1
#   method      stat  lags         p
# 0   kpss  0.351829     2  0.097918
#   method      stat  lags    p
# 0   kpss  0.191134     2  0.1
#   method      stat  lags    p
# 0   kpss  0.268172     2  0.1
#   method     stat  lags    p
# 0   kpss  0.24624     2  0.1
#   method      stat  lags    p
# 0   kpss  0.271105     2  0.1
#   method      stat  lags    p
# 0   kpss  0.122702     2  0.1
#   method      stat  lags         p
# 0   kpss  0.381098     2  0.085303
#   method      stat  lags    p
# 0   kpss  0.175911     2  0.1
#   method      stat  lags    p
# 0   kpss  0.263502     2  0.1
#   method      stat  lags    p
# 0   kpss  0.315712     2  0.1
#   method      stat  lags    p
# 0   kpss  0.188729     2  0.1
#   method      stat  lags    p
# 0   kpss  0.106401     2  0.1
#   method      stat  lags         p
# 0   kpss  0.484384     2  0.045184
#   method      stat  lags    p
# 0   kpss  0.229415     2  0.1
#   method      stat  lags    p
# 0   kpss  0.193573     2  0.1
#   method      stat  lags    p
# 0   kpss  0.185516     2  0.1
#   method      stat  lags    p
# 0   kpss  0.324667     2  0.1
#   method      stat  lags    p
# 0   kpss  0.172473     2  0.1
#   method     stat  lags    p
# 0   kpss  0.15946     2  0.1
#   method      stat  lags    p
# 0   kpss  0.163368     2  0.1
#   method      stat  lags    p
# 0   kpss  0.120409     2  0.1
#   method      stat  lags    p
# 0   kpss  0.285138     2  0.1
#   method      stat  lags    p
# 0   kpss  0.195427     2  0.1
#   method     stat  lags    p
# 0   kpss  0.21193     2  0.1
#   method      stat  lags    p
# 0   kpss  0.314363     2  0.1
#   method      stat  lags    p
# 0   kpss  0.172289     2  0.1
#   method      stat  lags    p
# 0   kpss  0.141829     2  0.1
#   method      stat  lags    p
# 0   kpss  0.154753     2  0.1
#   method      stat  lags    p
# 0   kpss  0.245662     2  0.1
#   method      stat  lags    p
# 0   kpss  0.237777     2  0.1
#   method      stat  lags    p
# 0   kpss  0.269964     2  0.1
#   method      stat  lags    p
# 0   kpss  0.123184     2  0.1
#   method      stat  lags         p
# 0   kpss  0.347344     2  0.099852
#   method      stat  lags    p
# 0   kpss  0.135682     2  0.1
#   method      stat  lags    p
# 0   kpss  0.209407     2  0.1
#   method      stat  lags    p
# 0   kpss  0.231928     2  0.1
#   method      stat  lags    p
# 0   kpss  0.249118     2  0.1
#   method      stat  lags    p
# 0   kpss  0.098526     2  0.1
#   method      stat  lags    p
# 0   kpss  0.159414     2  0.1

# %%
df = df[['state','year','criv','polpc']]
df = df.dropna()
df = panelDF(df,id='state',time='year')
df = df.outer_balance()
df['lcriv'] = np.log(df['criv'])
df['gcriv'] = df['lcriv'].diff()
df.loc[df['year']==80,'gcriv'] = np.nan
df['lpolpc'] = np.log(df['polpc'])
df['gpolpc'] = df['lpolpc'].diff()
df.loc[df['year']==80,'gpolpc'] = np.nan
df = df.dropna()
df = panelDF(df,id='state',time='year')

# %%
ddf = df.copy()
means_i = ddf[df.columns].groupby(df.id).mean().reset_index()[df.columns]
ddf -= np.kron(means_i,np.ones((len(df[df.time].unique()),1)))
means_t = ddf[df.columns].groupby(df.time).mean().reset_index()[df.columns]
ddf -= np.kron(np.ones((len(df[df.id].unique()),1)),means_t)

LeastSquaresRegressor(['lpolpc'],'lcriv',data=ddf).tidy
# Out:
#   variable             estimate            std.error        t.statistic  \
# 0   lpolpc  0.38493179181275955  0.06855469454216134  5.614958893530265
#
#                   p.value
# 0  2.8946908042274615e-08

# %%
LeastSquaresRegressor(['gpolpc'],'gcriv',data=ddf).tidy
# Out:
#   variable              estimate            std.error         t.statistic  \
# 0   gpolpc  0.044772693256053146  0.05779963803479563  0.7746189211271495
#
#               p.value
# 0  0.4388414459491329

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm
data = df.set_index(['state','year'])
dependent = data.gcriv
exog = sm.add_constant(data[['gpolpc']])
mod = PanelOLS(dependent, exog, entity_effects=True, time_effects=True)
res = mod.fit(cov_type='kernel')
res
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  gcriv   R-squared:                        0.0009
# Estimator:                   PanelOLS   R-squared (Between):              0.0126
# No. Observations:                 663   R-squared (Within):               0.0022
# Date:                Wed, Nov 16 2022   R-squared (Overall):              0.0028
# Time:                        19:27:16   Log-likelihood                    760.61
# Cov. Estimator:        Driscoll-Kraay
#                                         F-statistic:                      0.5429
# Entities:                          51   P-value                           0.4615
# Avg Obs:                       13.000   Distribution:                   F(1,599)
# Min Obs:                       13.000
# Max Obs:                       13.000   F-statistic (robust):             0.2902
#                                         P-value                           0.5903
# Time periods:                      13   Distribution:                   F(1,599)
# Avg Obs:                       51.000
# Min Obs:                       51.000
# Max Obs:                       51.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0156     0.0007     23.707     0.0000      0.0143      0.0168
# gpolpc         0.0448     0.0831     0.5387     0.5903     -0.1184      0.2080
# ==============================================================================
#
# F-test for Poolability: 2.8482
# P-value: 0.0000
# Distribution: F(62,599)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x165ab893100

# %% [markdown]
# # Programming challenge
#
# ## Panel Bootstrap
#
# Write a panel data bootstrap for the PRISON.csv data
